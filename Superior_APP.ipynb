# %% [markdown]
# <a href="https://colab.research.google.com/github/tuningrio2005/Superior/blob/main/Superior_APP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cd Superior
# !ls -t Superior/
# Out:
#  templates    'superior_v2 (2).zip'   sample_data   content    __pycache__
#  superior_v2   static		      app.py	    instance   requirements.txt

# %%
# %cd Superior
# !pip install -r requirements.txt
# Out:
# /content/Superior
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 48.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 78.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 7.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.45
#     Uninstalling SQLAlchemy-2.0.45:
#       Successfully uninstalled SQLAlchemy-2.0.45
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.2.1
#     Uninstalling python-dotenv-1.2.1:
#       Successfully uninstalled python-dotenv-1.2.1
#   Attempting uninstall: flask
#     Found existing installation: Flask 3.1.2
#     Uninstalling Flask-3.1.2:
#       Successfully uninstalled Flask-3.1.2
# ...

# %%
from google.colab import output
output.eval_js("google.colab.kernel.proxyPort(5000)")
# Out:
# 'https://5000-m-s-1hguz9b2q5m2v-c.us-east1-0.prod.colab.dev'

# %%
# !python app.py
# Out:
# >> RUNNING APP FROM: /content/Superior/app.py
#  * Serving Flask app 'app'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (inotify)
# >> RUNNING APP FROM: /content/Superior/app.py
#  * Debugger is active!
#  * Debugger PIN: 462-506-135
# 127.0.0.1 - - [15/Jan/2026 15:09:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jan/2026 15:09:27] "GET /static/img/Superior-Hoods-Logo.png HTTP/1.1" 404 -
# 127.0.0.1 - - [15/Jan/2026 15:09:27] "GET /static/styles.css?v=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jan/2026 15:09:27] "GET /favicon.ico HTTP/1.1" 404 -
# ...
